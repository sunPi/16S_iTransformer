# %%
# !wget -P data/16S_RNA/ https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.2_SSURef_NR99_tax_silva.fasta.gz
# !gunzip data/16S_RNA/SILVA_138.2_SSURef_NR99_tax_silva.fasta.gz

# !bash BASH/run_pipe -f data/16S_RNA/SILVA_138.2_SSURef_NR99_tax_silva.fasta -n 100 -l 10 -t 'itransformer'
# Out:
# BASH/run_pipe: line 4: /home/jovyan/bioinf-tools/bin/utils: No such file or directory
# Using iTransformer as the training algorithm.
# Processing FASTA file...
# /home/jovyan
# Loading SILVA fasta...
#           SampleID  ...                       species
# 0  AY846379.1.1791  ...                 Monoraphidium
# 1  AY846382.1.1778  ...                 Monoraphidium
# 2  AB000393.1.1510  ...            Vibrio halioticoli
# 3  AY909590.1.2352  ...                  Unclassified
# 4  AB000480.1.1326  ...  Insolitispirillum peregrinum
#
# [5 rows x 9 columns]
# (100, 9)
# Saved /home/jovyan/data/16S_RNA/singlelabel/silva_kingdom.pkl and .csv with 100 rows
# Saved /home/jovyan/data/16S_RNA/singlelabel/silva_phylum.pkl and .csv with 100 rows
# Saved /home/jovyan/data/16S_RNA/singlelabel/silva_class.pkl and .csv with 100 rows
# Saved /home/jovyan/data/16S_RNA/singlelabel/silva_order.pkl and .csv with 100 rows
# ...
